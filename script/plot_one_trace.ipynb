# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f1 = "./data/stm32/transfer_learning/12/data/08BF0EM/SNR4/700/minmax/X_profiling.npy"
f2 = "./data/stm32/transfer_learning/12/data/08BF0PW/SNR4/700/minmax/X_profiling.npy"

# %%
h1=np.load(f1)
h2=np.load(f2)

# %%
print(h1.shape)
# Out:
# (12500, 700)

# %%
plt.plot(h1[0, :])
plt.show()

# %%
plt.plot(h2[0, :])
plt.show()
